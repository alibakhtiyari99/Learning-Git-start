# %% [markdown]
# <a href="https://colab.research.google.com/github/alibakhtiyari99/Learning-Git-start/blob/main/git3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # تغییرات انجام شده

# %% [markdown]
# # log
#
# for seeing what happend in git use this:
#
#     $ git log

# %% [markdown]
# ![Screenshot 2025-02-19 163139.png](data:image/png;base64,...)

# %% [markdown]
# to see what happend now:
#
#     $ git status

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # HEAD
#
# in git HEAD called for last commit has done then compare now status to HEAD status. HEAD is not nesessary is last commit but by default!
#
#     $ git diff HEADH

# %% [markdown]
# in here `HEAD` is last commit had done, but can change!
#
# so examine latest status with latest commited status:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# in [above cmd](https://colab.research.google.com/drive/1u58xsT9cLvIW_f6UbnWsnGpK11MqspfM#scrollTo=dBwlZrCi0tqm&line=1&uniqifier=1) we see changes report printed. the `-` line is old line that edited to `+` line.

# %% [markdown]
# another command, this command show difference with stage:
#
#     $ git diff --staged
#
# if there is a problem, use this command to get out file file from stage:
#
#     $ git reset filename
#
# this command just bring the specific `file` from last commit and replace it with current:
#
#     $ git checkout --filename
