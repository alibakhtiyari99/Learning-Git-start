# %% [markdown]
# <a href="https://colab.research.google.com/github/alibakhtiyari99/Learning-Git-start/blob/main/git2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1 init

# %% [markdown]
# for creating git, first of all go to specific directory wants to use git by [commands like these](https://colab.research.google.com/drive/1NYaThizkpNk7wV5aMMagflZC4bJlJWJH#scrollTo=eqZe1cwuSyxN&line=1&uniqifier=1).
#
# first create new folder:

# %% [markdown]
# ## 1.1 create new folder

# %% [markdown]
# for creating new folder in CMD or Git BASH  use this command:
# ```
# >mkdir newFolder
# ```

# %% [markdown]
# ## 1.2 initiate Git

# %% [markdown]
# the we shoulde initiate Git in this direcrtiry by this command:
# ```
# >git init
# ```

# %% [markdown]
# after installing Git in windows, new App named **Git CMD** and **Git Bash** appear.
#
# this app is something like CMD but particullary for Git.
#
# but also there is another way to work with Git (that maybe not on all systems available) that when open CMD, there is an option for open new tab named **Git Bash**.

# %% [markdown]
# ![Screenshot 2025-02-19 153149.png](data:image/png;base64,...)

# %% [markdown]
# # 2 new file in CMD

# %% [markdown]
# for creating new file in CMD use this command:
# ```
# $ touch index.html
# ```
# NOTE that this ```touch``` action only works in Git Bash. but maybe there is other ways to create new file in a directory.

# %% [markdown]
# # 3 write in html file

# %% [markdown]
# for writin in html file first should open it with a notepad or text app.
#
# then add this script in text and save it:
# ```
# <html>
# <body>
# 	Hi there baby
# </body>
# </html>
# ```

# %% [markdown]
# # 4 check changes

# %% [markdown]
# use this command to see what hapend in a directory that
